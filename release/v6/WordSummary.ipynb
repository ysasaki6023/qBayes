# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
font = matplotlib.font_manager.FontProperties(fname='/Library/Fonts/Arial Unicode.ttf')

def myPlot(fpath,title,ansIdx,labelPos=[0.5,0.5]):
    d = pd.read_csv(fpath,encoding="shift-jis")
   # print d
    ansIdxCnt = len(set(d["answer_index"]))
    label0 = d["answer"][ansIdx]
    label1 = d["answer"][ansIdx+1]
    d = d[d["answer_index"]==ansIdx]

    fig = plt.figure(figsize=(5,5))#matplotlib.figure.figaspect(1))
    plt.scatter(d["accuracy"],d["error"],linewidth=0,s=10)
    plt.xlim(0,+1.0)
    plt.ylim(0,+1.0)
    plt.xlabel(u'正解率("%s")'%label0,fontproperties=font)
    if ansIdxCnt==2:
        plt.ylabel(u'正解率("%s")'%label1,fontproperties=font)
    else:
        plt.ylabel(u"不正解率",fontproperties=font)
    plt.title(title,fontproperties=font)

    print "------------------------------"
    print title
    print "------------------------------"
    for i,txy in enumerate(zip(d["word"],d["accuracy"],d["error"])):
        t,x,y = txy
        if abs(x-y)>0.3:
       # if (x>labelPos[0] and y<labelPos[1]) or (x<labelPos[1] and y>labelPos[0]):
            print "%10s (%.2f,%.2f)"%(t,x,y)
            plt.annotate(t, (x,y),xytext = (1.00,0.05),textcoords = 'offset points',ha = 'left', va = 'top', fontproperties=font,fontsize=8)

    plt.grid(True)
    plt.show()

myPlot("analysis/idx0.csv",u"貸与物の有無",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx1.csv",u"有形 / 無形",ansIdx=0,labelPos=(0.5,0.35))
myPlot("analysis/idx2.csv",u"汎用 / カスタマイズ",ansIdx=0,labelPos=(0.45,0.4))
myPlot("analysis/idx4.csv",u"ブランド価値",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx5.csv",u"経験曲線",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx7.csv",u"顧客蓄積",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx8.csv",u"情報蓄積",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx9.csv",u"中毒性",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx11.csv",u"地域制約",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx12.csv",u"特定顧客依存",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx13.csv",u"課金形態",ansIdx=0,labelPos=(0.45,0.45))
myPlot("analysis/idx15.csv",u"課金タイミング",ansIdx=0,labelPos=(0.5,0.4))

myPlot("analysis/idx6.csv",u"スイッチングコスト",ansIdx=1,labelPos=(0.5,0.42))
myPlot("analysis/idx6.csv",u"スイッチングコスト",ansIdx=2,labelPos=(0.5,0.42))
myPlot("analysis/idx3.csv",u"必須 / 特徴なし / 贅沢",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx3.csv",u"必須 / 特徴なし / 贅沢",ansIdx=1,labelPos=(0.5,0.4))
myPlot("analysis/idx3.csv",u"必須 / 特徴なし / 贅沢",ansIdx=2,labelPos=(0.5,0.4))
myPlot("analysis/idx10.csv",u"取引相手",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx10.csv",u"取引相手",ansIdx=1,labelPos=(0.5,0.4))
myPlot("analysis/idx10.csv",u"取引相手",ansIdx=2,labelPos=(0.5,0.4))
myPlot("analysis/idx14.csv",u"継続性",ansIdx=0,labelPos=(0.5,0.4))
myPlot("analysis/idx14.csv",u"継続性",ansIdx=1,labelPos=(0.5,0.4))
myPlot("analysis/idx14.csv",u"継続性",ansIdx=2,labelPos=(0.5,0.4))
# Out:
# ------------------------------
# 貸与物の有無
# ------------------------------
#         貸出 (0.34,0.02)
#         金利 (0.71,0.34)
#        不動産 (0.63,0.23)
#         事務 (0.41,0.07)
#         金融 (0.80,0.50)
#         製品 (0.29,0.68)
#         品質 (0.40,0.72)
#         銀行 (0.44,0.14)
#         出金 (0.31,0.00)
# ------------------------------
# 有形 / 無形
# ------------------------------
#         工場 (0.07,0.43)
#         請求 (0.52,0.21)
#         利用 (0.67,0.36)
#         製品 (0.36,0.75)
#    インターネット (0.45,0.14)
#       サービス (0.90,0.55)
#         不正 (0.53,0.18)
#          品 (0.21,0.54)
#        原材料 (0.09,0.51)
#         製造 (0.31,0.73)
#         漏洩 (0.58,0.27)
#     セキュリティ (0.52,0.18)
# ------------------------------
# 汎用 / カスタマイズ
# ------------------------------
#         案件 (0.13,0.47)
# ------------------------------
# ブランド価値
# ------------------------------
# ------------------------------
# 経験曲線
# ------------------------------
#         部品 (0.38,0.07)
#         製品 (0.89,0.45)
# ...
